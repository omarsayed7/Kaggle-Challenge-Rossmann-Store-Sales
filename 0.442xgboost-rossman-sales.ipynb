# %% [markdown]
# # Importing The Tools

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

from xgboost import  XGBRegressor
from xgboost import plot_importance

# %%
# %matplotlib inline

# %% [markdown]
# # Importing The Data and take a tour in the data

# %%
train_data = pd.read_csv("../input/train.csv")
test_data = pd.read_csv("../input/test.csv")
store_data = pd.read_csv("../input/store.csv")
test_copy = test_data
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print("Shape of Train data :", train_data.shape)
print("Shape of Test data :", test_data.shape)
print("Shape of Store data :", store_data.shape)
# Out:
# Shape of Train data : (1017209, 9)
# Shape of Test data : (41088, 8)
# Shape of Store data : (1115, 10)

# %%
train_data.head()
# Out:
#    Store  DayOfWeek      ...       StateHoliday  SchoolHoliday
# 0      1          5      ...                  0              1
# 1      2          5      ...                  0              1
# 2      3          5      ...                  0              1
# 3      4          5      ...                  0              1
# 4      5          5      ...                  0              1
#
# [5 rows x 9 columns]

# %%
test_data.head()
# Out:
#    Id  Store  DayOfWeek      ...       Promo  StateHoliday  SchoolHoliday
# 0   1      1          4      ...           1             0              0
# 1   2      3          4      ...           1             0              0
# 2   3      7          4      ...           1             0              0
# 3   4      8          4      ...           1             0              0
# 4   5      9          4      ...           1             0              0
#
# [5 rows x 8 columns]

# %%
store_data.head(100)
# Out:
#     Store StoreType        ...        Promo2SinceYear     PromoInterval
# 0       1         c        ...                    NaN               NaN
# 1       2         a        ...                 2010.0   Jan,Apr,Jul,Oct
# 2       3         a        ...                 2011.0   Jan,Apr,Jul,Oct
# 3       4         c        ...                    NaN               NaN
# 4       5         a        ...                    NaN               NaN
# 5       6         a        ...                    NaN               NaN
# 6       7         a        ...                    NaN               NaN
# 7       8         a        ...                    NaN               NaN
# 8       9         a        ...                    NaN               NaN
# 9      10         a        ...                    NaN               NaN
# 10     11         a        ...                 2012.0   Jan,Apr,Jul,Oct
# 11     12         a        ...                 2010.0   Jan,Apr,Jul,Oct
# 12     13         d        ...                 2009.0   Feb,May,Aug,Nov
# 13     14         a        ...                 2011.0   Jan,Apr,Jul,Oct
# 14     15         d        ...                 2011.0   Jan,Apr,Jul,Oct
# 15     16         a        ...                    NaN               NaN
# 16     17         a        ...                 2010.0   Jan,Apr,Jul,Oct
# 17     18         d        ...                 2012.0   Jan,Apr,Jul,Oct
# 18     19         a        ...                 2011.0  Mar,Jun,Sept,Dec
# 19     20         d        ...                 2014.0   Jan,Apr,Jul,Oct
# 20     21         c        ...                 2009.0   Jan,Apr,Jul,Oct
# 21     22         a        ...                 2012.0   Jan,Apr,Jul,Oct
# 22     23         d        ...                    NaN               NaN
# 23     24         a        ...                 2011.0   Jan,Apr,Jul,Oct
# 24     25         c        ...                    NaN               NaN
# 25     26         d        ...                    NaN               NaN
# 26     27         a        ...                 2011.0   Jan,Apr,Jul,Oct
# 27     28         a        ...                 2015.0  Mar,Jun,Sept,Dec
# 28     29         d        ...                    NaN               NaN
# 29     30         a        ...                 2014.0  Mar,Jun,Sept,Dec
# ..    ...       ...        ...                    ...               ...
# 70     71         a        ...                 2009.0  Mar,Jun,Sept,Dec
# 71     72         a        ...                 2010.0   Jan,Apr,Jul,Oct
# 72     73         a        ...                    NaN               NaN
# 73     74         a        ...                    NaN               NaN
# 74     75         d        ...                    NaN               NaN
# 75     76         d        ...                    NaN               NaN
# 76     77         d        ...                 2014.0   Jan,Apr,Jul,Oct
# 77     78         a        ...                 2013.0   Feb,May,Aug,Nov
# 78     79         a        ...                    NaN               NaN
# 79     80         d        ...                    NaN               NaN
# 80     81         a        ...                 2014.0   Jan,Apr,Jul,Oct
# 81     82         a        ...                 2009.0   Jan,Apr,Jul,Oct
# 82     83         a        ...                    NaN               NaN
# 83     84         a        ...                    NaN               NaN
# 84     85         b        ...                    NaN               NaN
# 85     86         a        ...                 2013.0   Jan,Apr,Jul,Oct
# 86     87         a        ...                    NaN               NaN
# 87     88         a        ...                    NaN               NaN
# 88     89         a        ...                 2014.0   Jan,Apr,Jul,Oct
# 89     90         a        ...                    NaN               NaN
# 90     91         c        ...                 2011.0   Jan,Apr,Jul,Oct
# 91     92         c        ...                 2009.0   Feb,May,Aug,Nov
# 92     93         a        ...                 2011.0   Jan,Apr,Jul,Oct
# 93     94         d        ...                    NaN               NaN
# 94     95         a        ...                    NaN               NaN
# 95     96         a        ...                 2009.0   Jan,Apr,Jul,Oct
# 96     97         d        ...                    NaN               NaN
# 97     98         d        ...                 2012.0   Jan,Apr,Jul,Oct
# 98     99         c        ...                 2012.0  Mar,Jun,Sept,Dec
# 99    100         d        ...                    NaN               NaN
#
# [100 rows x 10 columns]

# %%
train_data.isnull().sum()
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# Id                0
# Store             0
# DayOfWeek         0
# Date              0
# Open             11
# Promo             0
# StateHoliday      0
# SchoolHoliday     0
# dtype: int64

# %%
store_data.isnull().sum().sort_values(ascending = False)
# Out:
# PromoInterval                544
# Promo2SinceYear              544
# Promo2SinceWeek              544
# CompetitionOpenSinceYear     354
# CompetitionOpenSinceMonth    354
# CompetitionDistance            3
# Promo2                         0
# Assortment                     0
# StoreType                      0
# Store                          0
# dtype: int64

# %%
store_data['Promo2SinceWeek'].unique()
# Out:
# array([nan, 13., 14.,  1., 45., 40., 26., 22.,  5.,  6., 10., 31., 37.,
#         9., 39., 27., 18., 35., 23., 48., 36., 50., 44., 49., 28.])

# %%
train_data['Store'].unique()
# Out:
# array([   1,    2,    3, ..., 1113, 1114, 1115])

# %%
train_data['DayOfWeek'].unique()
# Out:
# array([5, 4, 3, 2, 1, 7, 6])

# %%
train_data['Open'].unique()
# Out:
# array([1, 0])

# %%
train_data['StateHoliday'].unique()
# Out:
# array(['0', 'a', 'b', 'c', 0], dtype=object)

# %%
train_data['Promo'].unique()
# Out:
# array([1, 0])

# %%
train_data['Store'].unique()
# Out:
# array([   1,    2,    3, ..., 1113, 1114, 1115])

# %%
store_data['CompetitionOpenSinceMonth'].unique()
# Out:
# array([ 9., 11., 12.,  4., 10.,  8., nan,  3.,  6.,  5.,  1.,  2.,  7.])

# %%
print(sum(train_data["Open"] == 0))
print(sum(train_data["Open"] == 1))
# Out:
# 172817
# 844392

# %%
print(sum(test_data["Open"] == 0))
print(sum(test_data["Open"] == 1))
# Out:
# 5984
# 35093

# %%
print(sum(train_data["StateHoliday"] == 'a'))
print(sum(train_data["StateHoliday"] == 'b'))
print(sum(train_data["StateHoliday"] == 'c'))
print(sum(train_data["StateHoliday"] == 0))
# Out:
# 20260
# 6690
# 4100
# 131072

# %%
plt.plot(train_data['DayOfWeek'],train_data['Customers'])

# %%
train_data[['Sales','Customers','Promo','SchoolHoliday']].corr(method='pearson')
# Out:
#                   Sales  Customers     Promo  SchoolHoliday
# Sales          1.000000   0.894711  0.452345       0.085124
# Customers      0.894711   1.000000  0.316169       0.071568
# Promo          0.452345   0.316169  1.000000       0.067483
# SchoolHoliday  0.085124   0.071568  0.067483       1.000000

# %%
train_data['Mon'] = train_data["Date"].apply(lambda x : int(x[5:7]))
train_data['Yr'] = train_data["Date"].apply(lambda x : int(x[:4]))
train_data["HolidayBin"] = train_data.StateHoliday.map({"0": 0, "a": 1, "b": 1, "c": 1})

# %%
test_data['Mon'] = test_data["Date"].apply(lambda x : int(x[5:7]))
test_data['Yr'] = test_data["Date"].apply(lambda x : int(x[:4]))
test_data["HolidayBin"] = test_data.StateHoliday.map({"0": 0, "a": 1, "b": 1, "c": 1})

# %%
train_data = train_data.merge(store_data)
test_data =test_data.merge(store_data)

# %%
train_data.head()
# Out:
#    Store  DayOfWeek      ...       Promo2SinceYear  PromoInterval
# 0      1          5      ...                   NaN            NaN
# 1      1          4      ...                   NaN            NaN
# 2      1          3      ...                   NaN            NaN
# 3      1          2      ...                   NaN            NaN
# 4      1          1      ...                   NaN            NaN
#
# [5 rows x 21 columns]

# %%
test_data.head()
# Out:
#      Id  Store      ...       Promo2SinceYear PromoInterval
# 0     1      1      ...                   NaN           NaN
# 1   857      1      ...                   NaN           NaN
# 2  1713      1      ...                   NaN           NaN
# 3  2569      1      ...                   NaN           NaN
# 4  3425      1      ...                   NaN           NaN
#
# [5 rows x 20 columns]

# %%
train_data.isnull().sum().sort_values(ascending= False)
# Out:
# PromoInterval                508031
# Promo2SinceWeek              508031
# Promo2SinceYear              508031
# CompetitionOpenSinceYear     323348
# CompetitionOpenSinceMonth    323348
# HolidayBin                   131072
# CompetitionDistance            2642
# Promo                             0
# DayOfWeek                         0
# Date                              0
# Sales                             0
# Customers                         0
# Open                              0
# Yr                                0
# StateHoliday                      0
# SchoolHoliday                     0
# Mon                               0
# StoreType                         0
# Assortment                        0
# Promo2                            0
# Store                             0
# dtype: int64

# %%
test_data.isnull().sum().sort_values(ascending= False)
# Out:
# PromoInterval                17232
# Promo2SinceWeek              17232
# Promo2SinceYear              17232
# CompetitionOpenSinceYear     15216
# CompetitionOpenSinceMonth    15216
# CompetitionDistance             96
# Open                            11
# StateHoliday                     0
# Store                            0
# DayOfWeek                        0
# Date                             0
# Promo                            0
# Yr                               0
# SchoolHoliday                    0
# Mon                              0
# HolidayBin                       0
# StoreType                        0
# Assortment                       0
# Promo2                           0
# Id                               0
# dtype: int64

# %%
test_data[test_data['Open'].isnull()]
# Out:
#           Id  Store      ...       Promo2SinceYear PromoInterval
# 22992    480    622      ...                   NaN           NaN
# 22993   1336    622      ...                   NaN           NaN
# 22994   2192    622      ...                   NaN           NaN
# 22995   3048    622      ...                   NaN           NaN
# 22997   4760    622      ...                   NaN           NaN
# 22998   5616    622      ...                   NaN           NaN
# 22999   6472    622      ...                   NaN           NaN
# 23000   7328    622      ...                   NaN           NaN
# 23001   8184    622      ...                   NaN           NaN
# 23002   9040    622      ...                   NaN           NaN
# 23004  10752    622      ...                   NaN           NaN
#
# [11 rows x 20 columns]

# %%
for i in train_data['Promo2SinceWeek'].unique() :
    print(i ,':', sum(train_data['Promo2SinceWeek'] == i ))
# Out:
# nan : 0
# 13.0 : 29820
# 14.0 : 72990
# 1.0 : 32418
# 45.0 : 29268
# 40.0 : 62598
# 26.0 : 942
# 22.0 : 28694
# 5.0 : 35818
# 6.0 : 942
# 10.0 : 38828
# 31.0 : 39976
# 37.0 : 32786
# 9.0 : 12452
# 39.0 : 4732
# 27.0 : 9626
# 18.0 : 27318
# 35.0 : 22814
# 23.0 : 4342
# 48.0 : 8294
# 36.0 : 9236
# 50.0 : 942
# 44.0 : 2642
# 49.0 : 758
# 28.0 : 942

# %%
for i in train_data['CompetitionOpenSinceMonth'].unique() :
    print(i ,':', sum(train_data['CompetitionOpenSinceMonth'] == i ))
# Out:
# 9.0 : 114254
# 11.0 : 84455
# 12.0 : 57896
# 4.0 : 87076
# 10.0 : 55622
# 8.0 : 36186
# nan : 0
# 3.0 : 63548
# 6.0 : 45444
# 5.0 : 39608
# 1.0 : 12452
# 2.0 : 37886
# 7.0 : 59434

# %%
for i in train_data['Promo2SinceYear'].unique() :
    print(i ,':', sum(train_data['Promo2SinceYear'] == i ))
# Out:
# nan : 0
# 2010.0 : 56240
# 2011.0 : 115056
# 2012.0 : 73174
# 2009.0 : 65270
# 2014.0 : 79922
# 2015.0 : 9052
# 2013.0 : 110464

# %%
for i in train_data['CompetitionOpenSinceYear'].unique() :
    print(i ,':', sum(train_data['CompetitionOpenSinceYear'] == i ))
# Out:
# 2008.0 : 48476
# 2007.0 : 43744
# 2006.0 : 42802
# 2009.0 : 49396
# 2015.0 : 35060
# 2013.0 : 75426
# 2014.0 : 63732
# 2000.0 : 9236
# 2011.0 : 49396
# nan : 0
# 2010.0 : 51258
# 2005.0 : 56564
# 1999.0 : 7352
# 2003.0 : 16794
# 2012.0 : 74299
# 2004.0 : 19804
# 2002.0 : 24882
# 1961.0 : 942
# 1995.0 : 1700
# 2001.0 : 14704
# 1990.0 : 4710
# 1994.0 : 1884
# 1900.0 : 758
# 1998.0 : 942

# %% [markdown]
# # Drop Some Data

# %%
train_data = train_data.drop(['Customers', 'Store','Date','StateHoliday'],axis= 1 )
test_data = test_data.drop(['Date','StateHoliday','Store','Id'],axis= 1 )

# %%
train_data.head()
# Out:
#    DayOfWeek  Sales      ...        Promo2SinceYear  PromoInterval
# 0          5   5263      ...                    NaN            NaN
# 1          4   5020      ...                    NaN            NaN
# 2          3   4782      ...                    NaN            NaN
# 3          2   5011      ...                    NaN            NaN
# 4          1   6102      ...                    NaN            NaN
#
# [5 rows x 17 columns]

# %%
test_data.head()
# Out:
#    DayOfWeek  Open      ...        Promo2SinceYear  PromoInterval
# 0          4   1.0      ...                    NaN            NaN
# 1          3   1.0      ...                    NaN            NaN
# 2          2   1.0      ...                    NaN            NaN
# 3          1   1.0      ...                    NaN            NaN
# 4          7   0.0      ...                    NaN            NaN
#
# [5 rows x 16 columns]

# %%
sum(train_data['Open'] == 0)
# Out:
# 172817

# %%
train_data = train_data.drop(train_data[train_data['Open'] == 0].index.tolist())

# %%
sum(train_data['Open'] == 0)
# Out:
# 0

# %%
train_data.shape
# Out:
# (844392, 17)

# %%
train_data[train_data['HolidayBin'].isnull()]
# Out:
#          DayOfWeek  Sales        ...         Promo2SinceYear     PromoInterval
# 310              3   3405        ...                     NaN               NaN
# 311              2   3407        ...                     NaN               NaN
# 312              1   3982        ...                     NaN               NaN
# 314              6   3911        ...                     NaN               NaN
# 315              5   4128        ...                     NaN               NaN
# 316              4   3740        ...                     NaN               NaN
# 317              3   4383        ...                     NaN               NaN
# 318              2   4381        ...                     NaN               NaN
# 319              1   4611        ...                     NaN               NaN
# 321              6   4270        ...                     NaN               NaN
# 322              5   3906        ...                     NaN               NaN
# 323              4   3392        ...                     NaN               NaN
# 324              3   3275        ...                     NaN               NaN
# 325              2   3377        ...                     NaN               NaN
# 326              1   3676        ...                     NaN               NaN
# 328              6   3959        ...                     NaN               NaN
# 329              5   4706        ...                     NaN               NaN
# 330              4   4346        ...                     NaN               NaN
# 331              3   4978        ...                     NaN               NaN
# 332              2   5008        ...                     NaN               NaN
# 333              1   5464        ...                     NaN               NaN
# 335              6   4094        ...                     NaN               NaN
# 336              5   3869        ...                     NaN               NaN
# 337              4   3920        ...                     NaN               NaN
# 338              3   3148        ...                     NaN               NaN
# 339              2   3396        ...                     NaN               NaN
# 340              1   3414        ...                     NaN               NaN
# 342              6   3582        ...                     NaN               NaN
# 343              5   3971        ...                     NaN               NaN
# 344              4   4327        ...                     NaN               NaN
# ...            ...    ...        ...                     ...               ...
# 1016791          6   6575        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016792          5   7226        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016793          4   6257        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016794          3   6977        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016795          2   6839        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016796          1   7952        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016798          6   6462        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016799          5   5966        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016800          4   4591        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016801          3   3982        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016802          2   3937        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016803          1   4283        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016805          6   6575        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016806          5   6621        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016807          4   6461        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016808          3   6148        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016809          2   6703        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016810          1   8646        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016812          6   7490        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016813          5   5829        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016814          4   4739        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016815          3   3858        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016816          2   4018        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016817          1   4043        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016819          6   6245        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016820          5   6388        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016821          4   6514        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016822          3   6223        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016823          2   6809        ...                  2012.0  Mar,Jun,Sept,Dec
# 1016824          1   8924        ...                  2012.0  Mar,Jun,Sept,Dec
#
# [112140 rows x 17 columns]

# %% [markdown]
# # Missing Values Cleaning

# %%
train_data['CompetitionOpenSinceMonth'] = train_data['CompetitionOpenSinceMonth'].fillna(9.0)
train_data['HolidayBin'] = train_data['HolidayBin'].fillna(0)
train_data['PromoInterval'] = train_data['PromoInterval'].fillna('Jan,Apr,Jul,Oct')
train_data['Promo2SinceWeek'] = train_data['Promo2SinceWeek'].fillna(40.0)
train_data['Promo2SinceYear'] = train_data['Promo2SinceYear'].fillna(2012.0)
train_data['CompetitionOpenSinceYear'] = train_data['CompetitionOpenSinceYear'].fillna(2012.0)
train_data['CompetitionDistance'] = train_data['CompetitionDistance'].fillna(train_data['CompetitionDistance'].mean())

train_data.isnull().sum().sort_values(ascending = False)
# Out:
# PromoInterval                0
# HolidayBin                   0
# Sales                        0
# Open                         0
# Promo                        0
# SchoolHoliday                0
# Mon                          0
# Yr                           0
# StoreType                    0
# Promo2SinceYear              0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# DayOfWeek                    0
# dtype: int64

# %%
test_data['Open'] = test_data['Open'].fillna(1)
test_data['CompetitionOpenSinceMonth'] = test_data['CompetitionOpenSinceMonth'].fillna(9.0)
test_data['CompetitionDistance'] = test_data['CompetitionDistance'].fillna(train_data['CompetitionDistance'].mean())
test_data['CompetitionOpenSinceYear'] = test_data['CompetitionOpenSinceYear'].fillna(2012.0)
test_data['Promo2SinceWeek'] = test_data['Promo2SinceWeek'].fillna(40.0)
test_data['Promo2SinceYear'] = test_data['Promo2SinceYear'].fillna(2012.0)
test_data['PromoInterval'] = test_data['PromoInterval'].fillna('Jan,Apr,Jul,Oct')

test_data.isnull().sum().sort_values(ascending = False)
# Out:
# PromoInterval                0
# Promo2SinceYear              0
# Promo2SinceWeek              0
# Promo2                       0
# CompetitionOpenSinceYear     0
# CompetitionOpenSinceMonth    0
# CompetitionDistance          0
# Assortment                   0
# StoreType                    0
# HolidayBin                   0
# Yr                           0
# Mon                          0
# SchoolHoliday                0
# Promo                        0
# Open                         0
# DayOfWeek                    0
# dtype: int64

# %%
train_data.shape
# Out:
# (844392, 17)

# %%
sum(train_data['Sales'] < 0 )
# Out:
# 0

# %%
test_data.shape
# Out:
# (41088, 16)

# %%
train_data.head(100)
# Out:
#      DayOfWeek  Sales       ...         Promo2SinceYear    PromoInterval
# 0            5   5263       ...                  2012.0  Jan,Apr,Jul,Oct
# 1            4   5020       ...                  2012.0  Jan,Apr,Jul,Oct
# 2            3   4782       ...                  2012.0  Jan,Apr,Jul,Oct
# 3            2   5011       ...                  2012.0  Jan,Apr,Jul,Oct
# 4            1   6102       ...                  2012.0  Jan,Apr,Jul,Oct
# 6            6   4364       ...                  2012.0  Jan,Apr,Jul,Oct
# 7            5   3706       ...                  2012.0  Jan,Apr,Jul,Oct
# 8            4   3769       ...                  2012.0  Jan,Apr,Jul,Oct
# 9            3   3464       ...                  2012.0  Jan,Apr,Jul,Oct
# 10           2   3558       ...                  2012.0  Jan,Apr,Jul,Oct
# 11           1   4395       ...                  2012.0  Jan,Apr,Jul,Oct
# 13           6   4406       ...                  2012.0  Jan,Apr,Jul,Oct
# 14           5   4852       ...                  2012.0  Jan,Apr,Jul,Oct
# 15           4   4427       ...                  2012.0  Jan,Apr,Jul,Oct
# 16           3   4767       ...                  2012.0  Jan,Apr,Jul,Oct
# 17           2   5042       ...                  2012.0  Jan,Apr,Jul,Oct
# 18           1   5054       ...                  2012.0  Jan,Apr,Jul,Oct
# 20           6   3530       ...                  2012.0  Jan,Apr,Jul,Oct
# 21           5   3808       ...                  2012.0  Jan,Apr,Jul,Oct
# 22           4   3897       ...                  2012.0  Jan,Apr,Jul,Oct
# 23           3   3797       ...                  2012.0  Jan,Apr,Jul,Oct
# 24           2   3650       ...                  2012.0  Jan,Apr,Jul,Oct
# 25           1   4359       ...                  2012.0  Jan,Apr,Jul,Oct
# 27           6   4797       ...                  2012.0  Jan,Apr,Jul,Oct
# 28           5   4665       ...                  2012.0  Jan,Apr,Jul,Oct
# 29           4   5558       ...                  2012.0  Jan,Apr,Jul,Oct
# 30           3   5223       ...                  2012.0  Jan,Apr,Jul,Oct
# 31           2   5735       ...                  2012.0  Jan,Apr,Jul,Oct
# 32           1   5197       ...                  2012.0  Jan,Apr,Jul,Oct
# 34           6   4019       ...                  2012.0  Jan,Apr,Jul,Oct
# ..         ...    ...       ...                     ...              ...
# 85           4   4529       ...                  2012.0  Jan,Apr,Jul,Oct
# 86           3   4960       ...                  2012.0  Jan,Apr,Jul,Oct
# 87           2   4564       ...                  2012.0  Jan,Apr,Jul,Oct
# 88           1   5591       ...                  2012.0  Jan,Apr,Jul,Oct
# 90           6   5850       ...                  2012.0  Jan,Apr,Jul,Oct
# 92           4   6228       ...                  2012.0  Jan,Apr,Jul,Oct
# 93           3   5775       ...                  2012.0  Jan,Apr,Jul,Oct
# 94           2   5199       ...                  2012.0  Jan,Apr,Jul,Oct
# 95           1   5575       ...                  2012.0  Jan,Apr,Jul,Oct
# 97           6   4318       ...                  2012.0  Jan,Apr,Jul,Oct
# 98           5   3198       ...                  2012.0  Jan,Apr,Jul,Oct
# 99           4   3076       ...                  2012.0  Jan,Apr,Jul,Oct
# 100          3   3319       ...                  2012.0  Jan,Apr,Jul,Oct
# 101          2   3037       ...                  2012.0  Jan,Apr,Jul,Oct
# 102          1   3722       ...                  2012.0  Jan,Apr,Jul,Oct
# 104          6   4594       ...                  2012.0  Jan,Apr,Jul,Oct
# 105          5   4718       ...                  2012.0  Jan,Apr,Jul,Oct
# 106          4   4116       ...                  2012.0  Jan,Apr,Jul,Oct
# 107          3   4110       ...                  2012.0  Jan,Apr,Jul,Oct
# 108          2   4648       ...                  2012.0  Jan,Apr,Jul,Oct
# 109          1   5377       ...                  2012.0  Jan,Apr,Jul,Oct
# 111          6   4173       ...                  2012.0  Jan,Apr,Jul,Oct
# 112          5   3549       ...                  2012.0  Jan,Apr,Jul,Oct
# 113          4   3467       ...                  2012.0  Jan,Apr,Jul,Oct
# 114          3   4194       ...                  2012.0  Jan,Apr,Jul,Oct
# 115          2   4163       ...                  2012.0  Jan,Apr,Jul,Oct
# 118          6   6709       ...                  2012.0  Jan,Apr,Jul,Oct
# 120          4   6574       ...                  2012.0  Jan,Apr,Jul,Oct
# 121          3   6816       ...                  2012.0  Jan,Apr,Jul,Oct
# 122          2   6206       ...                  2012.0  Jan,Apr,Jul,Oct
#
# [100 rows x 17 columns]

# %% [markdown]
# # Categorcal Data

# %%
categorical_train = train_data.columns.tolist()
print(categorical_train)
train_data[categorical_train].corr(method='pearson')
# Out:
# ['DayOfWeek', 'Sales', 'Open', 'Promo', 'SchoolHoliday', 'Mon', 'Yr', 'HolidayBin', 'StoreType', 'Assortment', 'CompetitionDistance', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval']
#                            DayOfWeek       ...         Promo2SinceYear
# DayOfWeek                   1.000000       ...                0.002710
# Sales                      -0.178736       ...               -0.008097
# Open                             NaN       ...                     NaN
# Promo                      -0.289265       ...               -0.001499
# SchoolHoliday              -0.139315       ...               -0.001546
# Mon                        -0.019723       ...               -0.002235
# Yr                          0.002102       ...               -0.000178
# HolidayBin                 -0.001959       ...                0.005100
# CompetitionDistance         0.005528       ...               -0.038799
# CompetitionOpenSinceMonth   0.000688       ...                0.006294
# CompetitionOpenSinceYear    0.001392       ...               -0.008390
# Promo2                     -0.003241       ...               -0.104285
# Promo2SinceWeek             0.001763       ...               -0.119213
# Promo2SinceYear             0.002710       ...                1.000000
#
# [14 rows x 14 columns]

# %% [markdown]
# ### Concatenate train and test data to be the same number of categorical labels

# %%
train_features = train_data.drop(['Open'],axis = 1)
categorical_train = train_features.columns.tolist()
print(categorical_train)
train_data[categorical_train].corr(method='pearson')
train_features = train_data.drop(['Sales'],axis = 1)
full_features = pd.concat([train_features,test_data],ignore_index= True)
print(train_features.shape)
print(test_data.shape)
# Out:
# ['DayOfWeek', 'Sales', 'Promo', 'SchoolHoliday', 'Mon', 'Yr', 'HolidayBin', 'StoreType', 'Assortment', 'CompetitionDistance', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval']
# (844392, 16)
# (41088, 16)

# %%
full_features.head()
# Out:
#    DayOfWeek  Open       ...         Promo2SinceYear    PromoInterval
# 0          5   1.0       ...                  2012.0  Jan,Apr,Jul,Oct
# 1          4   1.0       ...                  2012.0  Jan,Apr,Jul,Oct
# 2          3   1.0       ...                  2012.0  Jan,Apr,Jul,Oct
# 3          2   1.0       ...                  2012.0  Jan,Apr,Jul,Oct
# 4          1   1.0       ...                  2012.0  Jan,Apr,Jul,Oct
#
# [5 rows x 16 columns]

# %%
full_features.shape
# Out:
# (885480, 16)

# %%
full_features = pd.get_dummies(full_features,columns= ['PromoInterval','HolidayBin','Assortment','StoreType'])

# %%
full_features.shape
# Out:
# (885480, 24)

# %%
full_features = full_features.drop('DayOfWeek',axis = 1)

# %% [markdown]
# ### Split the train features and test features from full features data frame

# %%
train_features = full_features.iloc[:844392,:].values
test_data = full_features.iloc[844392:,:].values
train_sales = train_data['Sales'].values

# %%
print(train_features.shape)
print(train_sales.shape)
print(test_data.shape)
# Out:
# (844392, 23)
# (844392,)
# (41088, 23)

# %% [markdown]
# # Get the log of Sales

# %%
#train_sales = np.log(train_sales)

# %% [markdown]
# # Machine Learning Model

# %%
xgboost = XGBRegressor(learning_rate=0.009, n_estimators=100,
                                     max_depth=3, min_child_weight=0,
                                     gamma=0, subsample=0.7,
                                     colsample_bytree=0.7,
                                     objective='reg:linear', nthread=-1,
                                     scale_pos_weight=1, seed=27,
                                     reg_alpha=0.00006, random_state=42)

# %%
xgboost.fit(train_features,train_sales)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.7, gamma=0, importance_type='gain',
#        learning_rate=0.009, max_delta_step=0, max_depth=3,
#        min_child_weight=0, missing=None, n_estimators=100, n_jobs=1,
#        nthread=-1, objective='reg:linear', random_state=42,
#        reg_alpha=6e-05, reg_lambda=1, scale_pos_weight=1, seed=27,
#        silent=True, subsample=0.7)

# %%
predictions = xgboost.predict(test_data)

# %% [markdown]
# # Get the exp of predections

# %%
#preds = np.exp(predictions)

# %% [markdown]
# # Submission File

# %%
pred_df = pd.DataFrame({"Id": test_copy["Id"], 'Sales': predictions})
pred_df.to_csv("xgboost_4_submission.csv", index=False)
